# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import uproot

# %%
f = uproot.open("input_files/checkout_bnb_overlay_test_85files_noweights.root")
f.items()
# Out:
# [('nuselection;1', <ReadOnlyDirectory '/nuselection' at 0x00016ad53520>),
#  ('nuselection/NeutrinoSelectionFilter;1',
#   <TTree 'NeutrinoSelectionFilter' (856 branches) at 0x00016ad53280>),
#  ('nuselection/SubRun;1', <TTree 'SubRun' (3 branches) at 0x00016ad53ac0>),
#  ('shrreco3d;1', <ReadOnlyDirectory '/shrreco3d' at 0x00016ad531c0>),
#  ('shrreco3d/_energy_tree;1',
#   <TTree '_energy_tree' (6 branches) at 0x00016b8e61a0>),
#  ('shrreco3d/_dedx_tree;1',
#   <TTree '_dedx_tree' (24 branches) at 0x000106d216f0>),
#  ('shrreco3d/_rcshr_tree;1',
#   <TTree '_rcshr_tree' (23 branches) at 0x00016b8e6290>),
#  ('wcpselection;1', <ReadOnlyDirectory '/wcpselection' at 0x00016b93a2f0>),
#  ('wcpselection/T_eval;1', <TTree 'T_eval' (55 branches) at 0x00016b9862f0>),
#  ('wcpselection/T_pot;1', <TTree 'T_pot' (6 branches) at 0x000106d23550>),
#  ('wcpselection/T_PFeval;1',
#   <TTree 'T_PFeval' (137 branches) at 0x00016b9863e0>),
#  ('wcpselection/T_spacepoints;1',
# ...

# %%
f["wcpselection"].items()
# Out:
# [('T_eval;1', <TTree 'T_eval' (55 branches) at 0x00016b9862f0>),
#  ('T_pot;1', <TTree 'T_pot' (6 branches) at 0x000106d23550>),
#  ('T_PFeval;1', <TTree 'T_PFeval' (137 branches) at 0x00016b9863e0>),
#  ('T_spacepoints;1', <TTree 'T_spacepoints' (12 branches) at 0x00016ba21810>),
#  ('T_BDTvars;1', <TTree 'T_BDTvars' (825 branches) at 0x000106d23a60>),
#  ('T_KINEvars;1', <TTree 'T_KINEvars' (18 branches) at 0x00016b9863b0>)]

# %%
f["wcpselection"]["T_PFeval"]["reco_mother"].array()
# Out:
# <Array [[0, 0, 31005, ..., 0, 31009, 42022], ...] type='13778 * var * int32'>

# %%
plt.figure(figsize=(12, 5))
plt.subplot(121)
plt.scatter(f["wcpselection"]["T_spacepoints"]["Trec_spacepoints_y"].array()[0], f["wcpselection"]["T_spacepoints"]["Trec_spacepoints_x"].array()[0], c=f["wcpselection"]["T_spacepoints"]["Trec_spacepoints_q"].array()[0], s=1)
plt.colorbar(label="Track vs Shower")
plt.xlabel("y (cm)")
plt.ylabel("x (cm)")
plt.title("T_rec spacepoints - XY view")
plt.subplot(122)
plt.scatter(f["wcpselection"]["T_spacepoints"]["Trec_spacepoints_z"].array()[0], f["wcpselection"]["T_spacepoints"]["Trec_spacepoints_x"].array()[0], c=f["wcpselection"]["T_spacepoints"]["Trec_spacepoints_q"].array()[0], s=1)
plt.colorbar(label="Track vs Shower")
plt.xlabel("z (cm)")
plt.ylabel("x (cm)")
plt.title("T_rec spacepoints - ZY view")
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 5))
plt.subplot(121)
plt.scatter(f["wcpselection"]["T_spacepoints"]["Treccharge_spacepoints_y"].array()[0], f["wcpselection"]["T_spacepoints"]["Treccharge_spacepoints_x"].array()[0], c=f["wcpselection"]["T_spacepoints"]["Treccharge_spacepoints_q"].array()[0], s=1)
plt.colorbar(label="Charge")
plt.xlabel("y (cm)")
plt.ylabel("x (cm)")
plt.title("T_reccharge spacepoints - XY view")
plt.subplot(122)
plt.scatter(f["wcpselection"]["T_spacepoints"]["Treccharge_spacepoints_z"].array()[0], f["wcpselection"]["T_spacepoints"]["Treccharge_spacepoints_x"].array()[0], c=f["wcpselection"]["T_spacepoints"]["Treccharge_spacepoints_q"].array()[0], s=1)
plt.colorbar(label="Charge")
plt.xlabel("z (cm)")
plt.ylabel("x (cm)")
plt.title("T_reccharge spacepoints - ZY view")
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 5))
plt.subplot(121)
plt.scatter(f["wcpselection"]["T_spacepoints"]["Trecchargeblob_spacepoints_y"].array()[0], f["wcpselection"]["T_spacepoints"]["Trecchargeblob_spacepoints_x"].array()[0], c=f["wcpselection"]["T_spacepoints"]["Trecchargeblob_spacepoints_q"].array()[0], s=1)
plt.colorbar(label="Charge")
plt.xlabel("y (cm)")
plt.ylabel("x (cm)")
plt.title("T_recchargeblob spacepoints - XY view")
plt.subplot(122)
plt.scatter(f["wcpselection"]["T_spacepoints"]["Trecchargeblob_spacepoints_z"].array()[0], f["wcpselection"]["T_spacepoints"]["Trecchargeblob_spacepoints_x"].array()[0], c=f["wcpselection"]["T_spacepoints"]["Trecchargeblob_spacepoints_q"].array()[0], s=1)
plt.colorbar(label="Charge")
plt.xlabel("z (cm)")
plt.ylabel("x (cm)")
plt.title("T_recchargeblob spacepoints - ZY view")
plt.tight_layout()
plt.show()
