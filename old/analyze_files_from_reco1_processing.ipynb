# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd

# %%
reco1_file = "input_files/newly_processed_files/PhysicsRun-2017_11_5_4_50_23-0013779-00270_20190207T153317_ext_unbiased_2_20190610T213810_simmxd_20190610T233509_g4_detsim_mix_r1a_r1b_postdlmctruth_r1c_postwcct_postdlmc.root"

nominal_celltree_file = "input_files/newly_processed_files/PhysicsRun-2017_11_5_4_50_23-0013779-00270_20190207T153317_ext_unbiased_2_20190610T213810_simmxd_20190610T233509_g4_detsim_mix_r1a_r1b_postdlmctruth_r1c_postwcct_postdlmc_detsim_mix_postwcct.root"

merge_file = "input_files/newly_processed_files/merge.root"

nominal_slimmed_port_file = "input_files/newly_processed_files/PhysicsRun-2017_11_5_4_50_23-0013779-00270_20190207T153317_ext_unbiased_2_20190610T213810_simmxd_20190610T233509_g4_detsim_mix_r1a_r1b_postdlmctruth_r1c_postwcct_postdlmc_detsim_mix_postwcct_20241126T195201_overlayWCP.root"
nominal_plus_port_file = "input_files/newly_processed_files/PhysicsRun-2017_11_5_4_50_23-0013779-00270_20190207T153317_ext_unbiased_2_20190610T213810_simmxd_20190610T233509_g4_detsim_mix_r1a_r1b_postdlmctruth_r1c_postwcct_postdlmc_detsim_mix_postwcct_20241126T195201_overlayWCP_20241126T195312_WCPplus.root"
nominal_pf_port_file = "input_files/newly_processed_files/shorter_filename_WCPplus_20241127T171047_WCPF.root"
# GENIE reweight added files are in between here
nominal_reco2_file = "input_files/newly_processed_files/RootOutput-5e6e-23ef-939b-fad9_20241127T215718_WCPsl.root"
nominal_ntuple_file = "input_files/newly_processed_files/reco_stage_2_hist.root"

# just T_rec added
#new_spacepoint_slimmed_port_file = "input_files/newly_processed_files/new_with_spacepoints/PhysicsRun-2017_11_5_4_50_23-0013779-00270_20190207T153317_ext_unbiased_2_20190610T213810_simmxd_20190610T233509_g4_detsim_mix_r1a_r1b_postdlmctruth_r1c_postwcct_postdlmc_detsim_mix_postwcct_20241203T230150_overlayWCP.root"
#new_spacepoint_slimmed_port_file = "input_files/newly_processed_files/new_with_spacepoints/PhysicsRun-2017_11_5_4_50_23-0013779-00270_20190207T153317_ext_unbiased_2_20190610T213810_simmxd_20190610T233509_g4_detsim_mix_r1a_r1b_postdlmctruth_r1c_postwcct_postdlmc_detsim_mix_postwcct_20241204T163338_overlayWCP.root"
new_spacepoint_slimmed_port_file = "input_files/newly_processed_files/new_with_spacepoints/PhysicsRun-2017_11_5_4_50_23-0013779-00270_20190207T153317_ext_unbiased_2_20190610T213810_simmxd_20190610T233509_g4_detsim_mix_r1a_r1b_postdlmctruth_r1c_postwcct_postdlmc_detsim_mix_postwcct_20241204T171026_overlayWCP.root"

# only minimal spacepoints, processed interactively
#new_spacepoint_reco2_file = "input_files/newly_processed_files/new_with_spacepoints/RootOutput-3dec-3284-ddf5-26e0.root"

# from Ben 1
#new_spacepoint_reco2_file = "input_files/newly_processed_files/new_with_spacepoints/PhysicsRun-2017_11_5_4_50_23-0013779-00270_20190207T153317_ext_unbiased_2_20190610T213810_simmxd_20190610T233509_g4_detsim_mix_r1a_r1b_postdlmctruth_r_71acce78-53ca-4b32-b67f-e89461f06b19.root"

# from Ben 2
#new_spacepoint_reco2_file = "input_files/newly_processed_files/new_with_spacepoints/PhysicsRun-2017_11_5_4_50_23-0013779-00270_20190207T153317_ext_unbiased_2_20190610T213810_simmxd_20190610T233509_g4_detsim_mix_r1a_r1b_postdlmctruth_r_5da0431b-c753-468b-b57d-d793d418276d.root"

# from Ben 3, fixed, one event
#new_spacepoint_reco2_file = "input_files/newly_processed_files/new_with_spacepoints/PhysicsRun-2017_11_5_4_50_23-0013779-00270_20190207T153317_ext_unbiased_2_20190610T213810_simmxd_20190610T233509_g4_detsim_mix_r1a_r1b_postdlmctruth_r1c_postwcct_postdlmc_detsim_mix_postwcct.root"

# ncpi0 file from job
#new_spacepoint_reco2_file = "input_files/newly_processed_files/new_with_spacepoints/PhysicsRun-2017_11_5_4_50_23-0013779-00270_20190207T153317_ext_unbiased_2_20190610T213810_simmxd_20190610T233509_g4_detsim_mix_r1a_r1b_postdlmctruth_r_1ae2cef0-1c72-46bc-abc0-dcdb9a606cbc.root"

# update after re-adding default fhicls
#new_spacepoint_reco2_file = "input_files/newly_processed_files/new_with_spacepoints/PhysicsRun-2017_11_5_4_50_23-0013779-00270_20190207T153317_ext_unbiased_2_20190610T213810_simmxd_20190610T233509_g4_detsim_mix_r1a_r1b_postdlmctruth_r_98443e56-8fe1-4382-b7aa-70b4c719805d.root"


#new_spacepoint_reco2_file = "input_files/ben_numi_test_file/PhysicsRun-2018_12_22_1_17_13-0020407-00111_20190119T184844_ext_unbiased_2_gen_rhc_EW_20230107T150640_g4_detsim_mix_r1a_r1b_20230107T175536_reco1c_202_f3789bf0-b46f-49b4-a548-3f35d7d4d86d.root"


# these were when the PF step was failing due to a too long file name
#nominal_pf_port_file = "input_files/newly_processed_files/RootOutput-601c-1a89-abac-83f4.root"
#nominal_reco2_file = "input_files/newly_processed_files/RootOutput-540c-63a3-f506-9f90_20241126T212930_WCPsl.root"
#nominal_ntuple_file = "input_files/newly_processed_files/reco_stage_2_hist.root"

# %%
f = uproot.open("input_files/rec_charge_blob_ntuple_from_sp_file.root")
f["wcpselection"].items()
# Out:
# [('T_eval;1', <TTree 'T_eval' (55 branches) at 0x00016d028130>),
#  ('T_pot;1', <TTree 'T_pot' (6 branches) at 0x00016c5a1150>),
#  ('T_PFeval;1', <TTree 'T_PFeval' (137 branches) at 0x00016d02bf70>),
#  ('T_spacepoints;1', <TTree 'T_spacepoints' (4 branches) at 0x0001066379a0>),
#  ('T_BDTvars;1', <TTree 'T_BDTvars' (825 branches) at 0x00016d059600>),
#  ('T_KINEvars;1', <TTree 'T_KINEvars' (18 branches) at 0x00016d0b6650>)]

# %%
f["wcpselection"]["T_spacepoints"].items()
# Out:
# [('Trecchargeblob_spacepoints_x',
#   <TBranchElement 'Trecchargeblob_spacepoints_x' at 0x00016dc1ac80>),
#  ('Trecchargeblob_spacepoints_y',
#   <TBranchElement 'Trecchargeblob_spacepoints_y' at 0x00016dc1b610>),
#  ('Trecchargeblob_spacepoints_z',
#   <TBranchElement 'Trecchargeblob_spacepoints_z' at 0x00016dc1bf70>),
#  ('Trecchargeblob_spacepoints_q',
#   <TBranchElement 'Trecchargeblob_spacepoints_q' at 0x00016dc34910>)]

# %%
f["wcpselection"]["T_spacepoints"]["Trecchargeblob_spacepoints_x"].array()
# Out:
# <Array [[], [], [], [], [], ..., [], [], [], [], []] type='102 * var * float32'>

# %%
f["wcpselection"]["T_spacepoints"]["Trecchargeblob_spacepoints_y"].array()
# Out:
# <Array [[], [], [], [], [], ..., [], [], [], [], []] type='102 * var * float32'>

# %%
print(1/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(1/0)
#
# ZeroDivisionError: division by zero

# %%
old_spacepoint_reco2_file = "input_files/newly_processed_files/new_with_spacepoints/PhysicsRun-2017_11_5_4_50_23-0013779-00270_20190207T153317_ext_unbiased_2_20190610T213810_simmxd_20190610T233509_g4_detsim_mix_r1a_r1b_postdlmctruth_r_98443e56-8fe1-4382-b7aa-70b4c719805d.root"
f = uproot.open(old_spacepoint_reco2_file)
print("old file: ", f["Events"]["TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj"].items())

new_spacepoint_reco2_file = "input_files/ben_numi_test_file/PhysicsRun-2018_12_22_1_17_13-0020407-00111_20190119T184844_ext_unbiased_2_gen_rhc_EW_20230107T150640_g4_detsim_mix_r1a_r1b_20230107T175536_reco1c_202_f3789bf0-b46f-49b4-a548-3f35d7d4d86d.root"
f = uproot.open(new_spacepoint_reco2_file)
print("new file: ", f["Events"]["TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj"].items())

newer_spacepoint_reco_2_file = "input_files/ben_numi_test_file/PhysicsRun-2018_12_23_0_4_17-0020423-00220_20190114T102430_ext_unbiased_2_gen_rhc_EW_20230107T011318_g4_detsim_mix_r1a_r1b_20230107T024514_reco1c_2025_557775f4-e94a-427a-9568-f88f8a3b44b5.root"
f = uproot.open(new_spacepoint_reco2_file)
print("new file: ", f["Events"]["TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj"].items())
# Out:
# old file:  [('TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj.x', <TBranchElement 'TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj.x' at 0x00016da16ef0>), ('TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj.y', <TBranchElement 'TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj.y' at 0x00016da17ac0>), ('TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj.z', <TBranchElement 'TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj.z' at 0x00016dcd8460>), ('TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj.q', <TBranchElement 'TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj.q' at 0x00016dcd8dc0>), ('TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj.nq', <TBranchElement 'TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj.nq' at 0x00016dcd9720>), ('TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj.cluster_id', <TBranchElement 'TclusterSpacePoints_port
# ...

# %%
# Events/TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj.q

# %%
f = uproot.open(new_spacepoint_reco2_file)

for item in f["Events"].items():
    s = str(item)
    if "point" in s.lower() or "portedwc" in s.lower():
        print(s)
        pass
# Out:
# ('recob::SpacePoints_portedSpacePointsThreshold__PortRedux.', <TBranchElement 'recob::SpacePoints_portedSpacePointsThreshold__PortRedux.' (3 subbranches) at 0x00016b24d660>)
# ('recob::SpacePoints_portedSpacePointsThreshold__PortRedux./recob::SpacePoints_portedSpacePointsThreshold__PortRedux.present', <TBranchElement 'recob::SpacePoints_portedSpacePointsThreshold__PortRedux.present' at 0x00016b24db70>)
# ('recob::SpacePoints_portedSpacePointsThreshold__PortRedux./recob::SpacePoints_portedSpacePointsThreshold__PortRedux.rangeSetID', <TBranchElement 'recob::SpacePoints_portedSpacePointsThreshold__PortRedux.rangeSetID' at 0x00016b24e560>)
# ('recob::SpacePoints_portedSpacePointsThreshold__PortRedux./recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj', <TBranchElement 'recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj' at 0x00016b24ef20>)
# ...

# %%
f["Events"]["TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj"].items()
# Out:
# []

# %%
"""xyz = f["Events"]["recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]"].array(library="np")[1]
x = xyz[:, 0]
y = xyz[:, 1]
z = xyz[:, 2]

plt.figure(figsize=(10, 4))
plt.scatter(z, x, s=0.1)
plt.xlabel("z")
plt.ylabel("x")
plt.title("main_flag==1 spacepoints")
plt.xlim(750, 1000)
plt.ylim(175, 250)
plt.show()"""

x = f["Events"]["TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj.x"].array(library="np")[1]
y = f["Events"]["TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj.y"].array(library="np")[1]
z = f["Events"]["TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj.z"].array(library="np")[1]
q = f["Events"]["TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj.q"].array(library="np")[1]

plt.figure(figsize=(10, 4))
plt.scatter(z, x, c=q, s=0.1)
plt.colorbar(label="charge")
plt.xlabel("z")
plt.ylabel("x")
plt.title("WC T_cluster spacepoints")
plt.show()


x = f["Events"]["TrecSpacePoints_portedWCSpacePointsTrec__PortRedux.obj.x"].array(library="np")[1]
y = f["Events"]["TrecSpacePoints_portedWCSpacePointsTrec__PortRedux.obj.y"].array(library="np")[1]
z = f["Events"]["TrecSpacePoints_portedWCSpacePointsTrec__PortRedux.obj.z"].array(library="np")[1]
q = f["Events"]["TrecSpacePoints_portedWCSpacePointsTrec__PortRedux.obj.q"].array(library="np")[1]
id = f["Events"]["TrecSpacePoints_portedWCSpacePointsTrec__PortRedux.obj.real_cluster_id"].array(library="np")[1]

plt.figure(figsize=(10, 4))
plt.scatter(z, x, c=q, s=0.1)
plt.colorbar(label="charge")
plt.xlabel("z")
plt.ylabel("x")
plt.title("WC T_rec spacepoints")
plt.xlim(750, 1000)
plt.ylim(175, 250)
plt.show()

plt.figure(figsize=(10, 4))
plt.scatter(z, x, c=id, s=0.1)
plt.colorbar(label="real_cluster_id")
plt.xlabel("z")
plt.ylabel("x")
plt.title("WC T_rec spacepoints")
plt.xlim(750, 1000)
plt.ylim(175, 250)
plt.show()

x = f["Events"]["TrecchargeSpacePoints_portedWCSpacePointsTreccharge__PortRedux.obj.x"].array(library="np")[1]
y = f["Events"]["TrecchargeSpacePoints_portedWCSpacePointsTreccharge__PortRedux.obj.y"].array(library="np")[1]
z = f["Events"]["TrecchargeSpacePoints_portedWCSpacePointsTreccharge__PortRedux.obj.z"].array(library="np")[1]
q = f["Events"]["TrecchargeSpacePoints_portedWCSpacePointsTreccharge__PortRedux.obj.q"].array(library="np")[1]
id = f["Events"]["TrecchargeSpacePoints_portedWCSpacePointsTreccharge__PortRedux.obj.real_cluster_id"].array(library="np")[1]

plt.figure(figsize=(10, 4))
plt.scatter(z, x, c=q, s=0.1)
plt.colorbar(label="charge")
plt.xlabel("z")
plt.ylabel("x")
plt.title("WC T_rec_charge spacepoints")
plt.xlim(750, 1000)
plt.ylim(175, 250)
plt.show()

plt.figure(figsize=(10, 4))
plt.scatter(z, x, c=id, s=0.1)
plt.colorbar(label="real_cluster_id")
plt.xlabel("z")
plt.ylabel("x")
plt.title("WC T_rec_charge spacepoints")
plt.xlim(750, 1000)
plt.ylim(175, 250)
plt.show()

x = f["Events"]["TrecchargeblobSpacePoints_portedWCSpacePointsTrecchargeblob__PortRedux.obj.x"].array(library="np")[1]
y = f["Events"]["TrecchargeblobSpacePoints_portedWCSpacePointsTrecchargeblob__PortRedux.obj.y"].array(library="np")[1]
z = f["Events"]["TrecchargeblobSpacePoints_portedWCSpacePointsTrecchargeblob__PortRedux.obj.z"].array(library="np")[1]
q = f["Events"]["TrecchargeblobSpacePoints_portedWCSpacePointsTrecchargeblob__PortRedux.obj.q"].array(library="np")[1]
id = f["Events"]["TrecchargeblobSpacePoints_portedWCSpacePointsTrecchargeblob__PortRedux.obj.real_cluster_id"].array(library="np")[1]

plt.figure(figsize=(10, 4))
plt.scatter(z, x, c=q, s=0.1)
plt.colorbar(label="charge")
plt.xlabel("z")
plt.ylabel("x")
plt.title("WC T_rec_charge_blob spacepoints")
plt.xlim(750, 1000)
plt.ylim(175, 250)
plt.show()

plt.figure(figsize=(10, 4))
plt.scatter(z, x, c=id, s=0.1)
plt.colorbar(label="real_cluster_id")
plt.xlim(750, 1000)
plt.ylim(175, 250)
plt.xlabel("z")
plt.ylabel("x")
plt.title("WC T_rec_charge_blob spacepoints")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyInFileError                            Traceback (most recent call last)
# Cell In[5], line 15
#       1 """xyz = f["Events"]["recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]"].array(library="np")[1]
#       2 x = xyz[:, 0]
#       3 y = xyz[:, 1]
#    (...)
#      12 plt.ylim(175, 250)
#      13 plt.show()"""
# ---> 15 x = f["Events"]["TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj.x"].array(library="np")[1]
#      16 y = f["Events"]["TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj.y"].array(library="np")[1]
#      17 z = f["Events"]["TclusterSpacePoints_portedWCSpacePointsTcluster__PortRedux.obj.z"].array(library="np")[1]
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/base_2/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:1649, in HasBranches.__getitem__(self, where)
#    1647         return got
#    1648     else:
# ...

# %%
# always has two vectors per event, not any detailed shower geometry...
f["Events"]["sim::MCShowers_mcreco__G4EDep.obj.fStart._position"].array(library="np")[1]
# Out:
# array([<TLorentzVector (version 4) at 0x000176173760>,
#        <TLorentzVector (version 4) at 0x0001761737c0>], dtype=object)

# %%
f["Events"]["sim::MCShowers_mcreco__G4EDep.obj.fdEdx"].array(library="np")
# Out:
# array([array([0.49943337, 0.        ]), array([15.28847589,  5.13240188]),
#        array([0.       , 4.3664434]), array([0.        , 2.05487548]),
#        array([0.08849049, 0.        ]), array([0.31531774, 0.        ]),
#        array([0.03975772, 0.        ]), array([4.24805023, 1.14621197]),
#        array([5.15310767, 5.11437641]), array([4.30977704, 4.39728132]),
#        array([0.04914692, 0.22376344]), array([2.11168952, 5.342946  ]),
#        array([0., 0.]), array([4.90932359, 5.55648803]),
#        array([0.43213641, 2.56324389]), array([2.96841641, 6.45078359]),
#        array([4.38195403, 4.87968599]), array([0., 0.]),
#        array([5.93756811, 7.81078607]), array([11.45901895,  7.51971581]),
#        array([3.84614749, 4.17800213]), array([5.60253914, 4.19654854]),
#        array([0.        , 7.36369756]), array([25.64365602,  6.61275256]),
#        array([0.0911183, 0.       ]), array([4.8968642 , 4.38189576]),
# ...

# %%
f["Events"]["sim::SimEnergyDeposits_ionization__G4EDep.obj.startPos.fCoordinates.fX"].array(library="np")
# Out:
# array([array([-1.54999995, -1.54999995,  4.10911131, ...,  7.52175283,
#                7.52449274,  7.52449369])                              ,
#        array([201.08992004, 201.08992004, 201.07710266, ..., 227.73158264,
#               227.73576355, 227.73677063])                                ,
#        array([-1.54999995,  8.2588625 , 11.04098797, ..., 32.69507599,
#               32.69669342, 32.69643784])                              ,
#        array([111.58515167, 162.13510132, 164.47296143, ...,  44.6031456 ,
#                44.6043396 ,  44.72548294])                                ,
#        array([  9.76357079,  40.21725464,  38.40916443,  37.56227493,
#                40.12647629,  36.68613815,  41.36650848,  40.61513138,
#                72.00070953,  15.51993275,  22.37877464,  22.62015533,
#                23.47112465,   3.69068718,  -1.54999995,  13.38075829,
#                82.7612381 ,  73.15970612,  94.46426392,  93.70547485,
# ...

# %%
x_start = f["Events"]["sim::SimEnergyDeposits_ionization__G4EDep.obj.startPos.fCoordinates.fX"].array(library="np")[1]
y_start = f["Events"]["sim::SimEnergyDeposits_ionization__G4EDep.obj.startPos.fCoordinates.fY"].array(library="np")[1]
z_start = f["Events"]["sim::SimEnergyDeposits_ionization__G4EDep.obj.startPos.fCoordinates.fZ"].array(library="np")[1]

x_end = f["Events"]["sim::SimEnergyDeposits_ionization__G4EDep.obj.endPos.fCoordinates.fX"].array(library="np")[1]
y_end = f["Events"]["sim::SimEnergyDeposits_ionization__G4EDep.obj.endPos.fCoordinates.fY"].array(library="np")[1]
z_end = f["Events"]["sim::SimEnergyDeposits_ionization__G4EDep.obj.endPos.fCoordinates.fZ"].array(library="np")[1]

q = f["Events"]["sim::SimEnergyDeposits_ionization__G4EDep.obj.edep"].array(library="np")[1]

dists = np.sqrt((x_end - x_start)**2 + (y_end - y_start)**2 + (z_end - z_start)**2)

print(len(x_start), len(x_end), len(y_start), len(y_end), len(z_start), len(z_end))

norm = plt.Normalize(vmin=min(q), vmax=max(q))
import matplotlib.cm as cm
colormap = cm.plasma

plt.figure(figsize=(10, 6))
for i in range(len(x_start)):
    if dists[i] < 1:
        plt.plot([z_start[i], z_end[i]], [x_start[i], x_end[i]], c=colormap(norm(q[i])))
plt.colorbar(cm.ScalarMappable(norm=norm, cmap=colormap), label="ionization energy deposit")
plt.xlabel("z")
plt.ylabel("x")
plt.xlim(750, 1000)
plt.ylim(175, 250)
plt.show()
# Out:
# 8590 8590 8590 8590 8590 8590
# /var/folders/yg/3cj9svrx2kz3bpv_6thtt7x00000gn/T/ipykernel_18149/1042822921.py:23: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(cm.ScalarMappable(norm=norm, cmap=colormap), label="ionization energy deposit")

# %%
print(1/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(1/0)
#
# ZeroDivisionError: division by zero

# %%
start_positions = f["Events"]["sim::MCTracks_mcreco__G4EDep.obj.fStart._position"].array(library="np")[1]
end_positions = f["Events"]["sim::MCShowers_mcreco__G4EDep.obj.fEnd._position"].array(library="np")[1]

x_start = [p.member("fP").member("fX") for p in start_positions]
y_start = [p.member("fP").member("fY") for p in start_positions]
z_start = [p.member("fP").member("fZ") for p in start_positions]

x_end = [p.member("fP").member("fX") for p in end_positions]
y_end = [p.member("fP").member("fY") for p in end_positions]
z_end = [p.member("fP").member("fZ") for p in end_positions]

print(len(x_start), len(x_end))
print(len(y_start), len(y_end))
print(len(z_start), len(z_end))


plt.figure(figsize=(10, 6))

for i in range(len(x_start)):
    plt.plot([z_start[i], z_end[i]], [x_start[i], x_end[i]])
plt.legend()
plt.show()
# Out:
# 14 2
# 14 2
# 14 2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 20
#      17 plt.figure(figsize=(10, 6))
#      19 for i in range(len(x_start)):
# ---> 20     plt.plot([z_start[i], z_end[i]], [x_start[i], x_end[i]])
#      21 plt.legend()
#      22 plt.show()
#
# IndexError: list index out of range

# %%
f = uproot.open(nominal_reco2_file)

for item in f["Events"].items():
    if "G4EDep" in str(item):
        print(item)
# Out:
# ('simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep.', <TBranchElement 'simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep.' (3 subbranches) at 0x00034eb26650>)
# ('simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep./simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep.present', <TBranchElement 'simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep.present' at 0x00034eb26b60>)
# ('simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep./simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep.rangeSetID', <TBranchElement 'simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep.rangeSetID' at 0x00034eb274f0>)
# ...

# %%
print(1/0)

# %%
f = uproot.open(reco1_file)
#f = uproot.open(nominal_slimmed_port_file)

for item in f["Events"].items():
    if "G4EDep" in str(item):
        print(item)


f["Events"]["simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep.obj"]
# Out:
# ('simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep.', <TBranchElement 'simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep.' (3 subbranches) at 0x0003498b26e0>)
# ('simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep./simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep.present', <TBranchElement 'simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep.present' at 0x0003498b2bf0>)
# ('simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep./simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep.rangeSetID', <TBranchElement 'simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep.rangeSetID' at 0x0003498b3580>)
# ...

# %%
# 398 MB
f = uproot.open(nominal_celltree_file)

#spacepoint_xyz_by_event = f["Events"]["recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]"].array(library="np")

#print(f.items())
#f["Events"].items()

# no spacepoints in this file

# %%
f = uproot.open(merge_file)

f.items()
# Out:
# [('T_port_flash;1', <TTree 'T_port_flash' (10 branches) at 0x000127d4ab60>),
#  ('T_port_2d;1', <TTree 'T_port_2d' (8 branches) at 0x00010521b940>),
#  ('T_port_3d;1', <TTree 'T_port_3d' (13 branches) at 0x00010521bac0>),
#  ('T_eval;1', <TTree 'T_eval' (33 branches) at 0x000127d4ab00>)]

# %%
f["T_port_3d"].items()
# Out:
# [('run', <TBranch 'run' at 0x000127dcd750>),
#  ('subrun', <TBranch 'subrun' at 0x000127dcdf90>),
#  ('event', <TBranch 'event' at 0x000127dce740>),
#  ('main_flag', <TBranch 'main_flag' at 0x000127dceef0>),
#  ('time_slice', <TBranch 'time_slice' at 0x000127dcf6a0>),
#  ('ch_u', <TBranch 'ch_u' at 0x000127dcfe50>),
#  ('ch_v', <TBranch 'ch_v' at 0x000127de0640>),
#  ('ch_w', <TBranch 'ch_w' at 0x000127de0df0>),
#  ('x', <TBranch 'x' at 0x000127de15a0>),
#  ('y', <TBranch 'y' at 0x000127de1d50>),
#  ('z', <TBranch 'z' at 0x000127de2500>),
#  ('q', <TBranch 'q' at 0x000127de2ce0>),
#  ('nq', <TBranch 'nq' at 0x000127de3490>)]

# %%
main_flag = f["T_port_3d"]["main_flag"].array(library="np")

run = f["T_port_3d"]["run"].array(library="np")
subrun = f["T_port_3d"]["subrun"].array(library="np")
event = f["T_port_3d"]["event"].array(library="np")

x = f["T_port_3d"]["x"].array(library="np")
y = f["T_port_3d"]["y"].array(library="np")
z = f["T_port_3d"]["z"].array(library="np")
q = f["T_port_3d"]["q"].array(library="np")

df = pd.DataFrame({"run": run, "subrun": subrun, "event": event, "x": x, "y": y, "z": z, "q": q, "main_flag": main_flag})

df_one_event = df.query("run == 13779 and subrun == 223 and event == 11160")

plt.figure(figsize=(10, 6))
plt.scatter(df_one_event["z"], df_one_event["x"], c=df_one_event["q"], s=(df_one_event["q"]/10000)**3)
plt.colorbar(label="charge")
plt.xlabel("z")
plt.ylabel("x")
plt.title("merge.root/T_port_3d\nRSE 13779, 223, 11160")
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(df_one_event["z"], df_one_event["y"], c=df_one_event["q"], s=(df_one_event["q"]/10000)**3)
plt.colorbar(label="charge")
plt.xlabel("z")
plt.ylabel("y")
plt.title("merge.root/T_port_3d\nRSE 13779, 223, 11160")
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(df_one_event["z"], df_one_event["x"], c=df_one_event["main_flag"], s=1)
plt.colorbar(label="main_flag")
plt.xlabel("z")
plt.ylabel("x")
plt.title("merge.root/T_port_3d\nRSE 13779, 223, 11160")
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(df_one_event["z"], df_one_event["y"], c=df_one_event["main_flag"], s=1)
plt.colorbar(label="main_flag")
plt.xlabel("z")
plt.ylabel("y")
plt.title("merge.root/T_port_3d\nRSE 13779, 223, 11160")
plt.show()

# %%
# 400 MB
f = uproot.open(nominal_slimmed_port_file)

#print(f.items())
#f["Events"].items()

# there are spacepoints in this file

spacepoint_xyz_by_event = f["Events"]["recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]"].array(library="np")

spacepoint_xyz_one_event = spacepoint_xyz_by_event[8]

print(spacepoint_xyz_one_event.shape)

plt.figure(figsize=(10, 6))
plt.scatter(spacepoint_xyz_one_event[:, 2], spacepoint_xyz_one_event[:, 0], s=0.1)
plt.xlabel("z")
plt.ylabel("x")
plt.title("recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]\n slimmed_port_file")
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(spacepoint_xyz_one_event[:, 2], spacepoint_xyz_one_event[:, 1], s=0.1)
plt.xlabel("z")
plt.ylabel("y")
plt.title("recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]\n slimmed_port_file")
plt.show()

plt.figure(figsize=(6, 6))
plt.scatter(spacepoint_xyz_one_event[:, 0], spacepoint_xyz_one_event[:, 1], s=0.1)
plt.xlabel("x")
plt.ylabel("y")
plt.title("recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]\n slimmed_port_file")
plt.show()

f["Events"].items()
# Out:
# (2563, 3)
# [('EventAuxiliary', <TBranchElement 'EventAuxiliary' at 0x000176547130>),
#  ('art::TriggerResults_TriggerResults__DataOverlay.',
#   <TBranchElement 'art::TriggerResults_TriggerResults__DataOverlay.' (3 subbranches) at 0x000176869780>),
#  ('art::TriggerResults_TriggerResults__DataOverlay./art::TriggerResults_TriggerResults__DataOverlay.present',
#   <TBranchElement 'art::TriggerResults_TriggerResults__DataOverlay.present' at 0x000176869ba0>),
#  ('art::TriggerResults_TriggerResults__DataOverlay./art::TriggerResults_TriggerResults__DataOverlay.rangeSetID',
#   <TBranchElement 'art::TriggerResults_TriggerResults__DataOverlay.rangeSetID' at 0x00017686a590>),
#  ('art::TriggerResults_TriggerResults__DataOverlay./art::TriggerResults_TriggerResults__DataOverlay.obj',
#   <TBranchElement 'art::TriggerResults_TriggerResults__DataOverlay.obj' at 0x00017686a890>),
#  ('raw::ubdaqSoftwareTriggerData_swtrigger__DataOverlay.',
# ...

# %%
# 200 MB
f = uproot.open(nominal_plus_port_file)

# there are spacepoints in this file

spacepoint_xyz_by_event = f["Events"]["recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]"].array(library="np")

spacepoint_xyz_one_event = spacepoint_xyz_by_event[8]

print(spacepoint_xyz_one_event.shape)

plt.figure(figsize=(10, 6))
plt.scatter(spacepoint_xyz_one_event[:, 2], spacepoint_xyz_one_event[:, 0], s=0.1)
plt.xlabel("z")
plt.ylabel("x")
plt.title("recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]\n wcpplus_port_file")
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(spacepoint_xyz_one_event[:, 2], spacepoint_xyz_one_event[:, 1], s=0.1)
plt.xlabel("z")
plt.ylabel("y")
plt.title("recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]\n wcpplus_port_file")
plt.show()

plt.figure(figsize=(6, 6))
plt.scatter(spacepoint_xyz_one_event[:, 0], spacepoint_xyz_one_event[:, 1], s=0.1)
plt.xlabel("x")
plt.ylabel("y")
plt.title("recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]\n wcpplus_port_file")
plt.show()
# Out:
# (2563, 3)

# %%
f = uproot.open(nominal_pf_port_file)

for item in f["Events"].items():
    if "mcparticle" in str(item).lower():
        print(item)
# Out:
# ('simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep.', <TBranchElement 'simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep.' (3 subbranches) at 0x00032f590160>)
# ('simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep./simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep.present', <TBranchElement 'simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep.present' at 0x00032f590670>)
# ('simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep./simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep.rangeSetID', <TBranchElement 'simb::MCParticlesimb::MCTruthsim::GeneratedParticleInfoart::Assns_largeant__G4EDep.rangeSetID' at 0x00032f591000>)
# ...

# %%
# 181 MB
f = uproot.open(nominal_pf_port_file)

spacepoint_xyz_by_event = f["Events"]["recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]"].array(library="np")

spacepoint_xyz_one_event = spacepoint_xyz_by_event[8]

print(spacepoint_xyz_one_event.shape)

plt.figure(figsize=(10, 6))
plt.scatter(spacepoint_xyz_one_event[:, 2], spacepoint_xyz_one_event[:, 0], s=0.1)
plt.xlabel("z")
plt.ylabel("x")
plt.title("recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]\n wcpplus_port_file")
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(spacepoint_xyz_one_event[:, 2], spacepoint_xyz_one_event[:, 1], s=0.1)
plt.xlabel("z")
plt.ylabel("y")
plt.title("recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]\n wcpplus_port_file")
plt.show()

plt.figure(figsize=(6, 6))
plt.scatter(spacepoint_xyz_one_event[:, 0], spacepoint_xyz_one_event[:, 1], s=0.1)
plt.xlabel("x")
plt.ylabel("y")
plt.title("recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]\n wcpplus_port_file")
plt.show()
# Out:
# (2563, 3)

# %%
# 186 MB
f = uproot.open(nominal_reco2_file)

spacepoint_xyz_by_event = f["Events"]["recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]"].array(library="np")

spacepoint_xyz_one_event = spacepoint_xyz_by_event[8]

print(spacepoint_xyz_one_event.shape)

plt.figure(figsize=(10, 6))
plt.scatter(spacepoint_xyz_one_event[:, 2], spacepoint_xyz_one_event[:, 0], s=0.1)
plt.xlabel("z")
plt.ylabel("x")
plt.title("recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]\n wcpplus_port_file")
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(spacepoint_xyz_one_event[:, 2], spacepoint_xyz_one_event[:, 1], s=0.1)
plt.xlabel("z")
plt.ylabel("y")
plt.title("recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]\n wcpplus_port_file")
plt.show()

plt.figure(figsize=(6, 6))
plt.scatter(spacepoint_xyz_one_event[:, 0], spacepoint_xyz_one_event[:, 1], s=0.1)
plt.xlabel("x")
plt.ylabel("y")
plt.title("recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]\n wcpplus_port_file")
plt.show()
# Out:
# (2563, 3)

# %%
f = uproot.open(nominal_reco2_file)

f.items()
# Out:
# [('RootFileDB;1', <Unknown TKey at 0x00016ae640d0>),
#  ('MetaData;1', <TTree 'MetaData' (4 branches) at 0x00016d28cf10>),
#  ('FileIndex;1', <TTree 'FileIndex' (1 branches) at 0x00016ae64250>),
#  ('Parentage;1', <TTree 'Parentage' (2 branches) at 0x00033059f8e0>),
#  ('EventHistory;1', <TTree 'EventHistory' (1 branches) at 0x00016d2c1090>),
#  ('Events;1', <TTree 'Events' (170 branches) at 0x0003305b2260>),
#  ('EventMetaData;1', <TTree 'EventMetaData' (1 branches) at 0x00016d2c1f60>),
#  ('SubRuns;1', <TTree 'SubRuns' (2 branches) at 0x00032fa63880>),
#  ('SubRunMetaData;1', <TTree 'SubRunMetaData' (1 branches) at 0x00033059e950>),
#  ('Runs;1', <TTree 'Runs' (1 branches) at 0x00032fb1e2f0>),
#  ('RunMetaData;1', <TTree 'RunMetaData' (1 branches) at 0x00032fb1f2e0>),
#  ('ResultsTree;1', <TTree 'ResultsTree' (1 branches) at 0x00032fa628f0>),
#  ('ResultsMetaData;1',
#   <TTree 'ResultsMetaData' (1 branches) at 0x00033710d270>)]

# %%
f = uproot.open(nominal_reco2_file)

f["Events"]["simb::MCParticles_wirecellPF__PortPF.obj"].keys()
# Out:
# ['simb::MCParticles_wirecellPF__PortPF.obj.fstatus',
#  'simb::MCParticles_wirecellPF__PortPF.obj.ftrackId',
#  'simb::MCParticles_wirecellPF__PortPF.obj.fpdgCode',
#  'simb::MCParticles_wirecellPF__PortPF.obj.fmother',
#  'simb::MCParticles_wirecellPF__PortPF.obj.fprocess',
#  'simb::MCParticles_wirecellPF__PortPF.obj.fendprocess',
#  'simb::MCParticles_wirecellPF__PortPF.obj.ftrajectory.ftrajectory',
#  'simb::MCParticles_wirecellPF__PortPF.obj.ftrajectory.fTrajectoryProcess',
#  'simb::MCParticles_wirecellPF__PortPF.obj.fmass',
#  'simb::MCParticles_wirecellPF__PortPF.obj.fpolarization',
#  'simb::MCParticles_wirecellPF__PortPF.obj.fdaughters',
#  'simb::MCParticles_wirecellPF__PortPF.obj.fWeight',
#  'simb::MCParticles_wirecellPF__PortPF.obj.fGvtx',
#  'simb::MCParticles_wirecellPF__PortPF.obj.frescatter']

# %%
f = uproot.open(nominal_reco2_file)



pdg = f["Events"]["simb::MCParticles_wirecellPF__PortPF.obj.fpdgCode"].array(library="np")

for i in range(len(pdg)):
    print(len(pdg[i]))

# %%
# 1.2 MB
f = uproot.open(nominal_ntuple_file)

spacepoint_xyz_by_event = f["Events"]["recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]"].array(library="np")

spacepoint_xyz_one_event = spacepoint_xyz_by_event[8]

print(spacepoint_xyz_one_event.shape)

plt.figure(figsize=(10, 6))
plt.scatter(spacepoint_xyz_one_event[:, 2], spacepoint_xyz_one_event[:, 0], s=0.1)
plt.xlabel("z")
plt.ylabel("x")
plt.title("recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]\n wcpplus_port_file")
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(spacepoint_xyz_one_event[:, 2], spacepoint_xyz_one_event[:, 1], s=0.1)
plt.xlabel("z")
plt.ylabel("y")
plt.title("recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]\n wcpplus_port_file")
plt.show()

plt.figure(figsize=(6, 6))
plt.scatter(spacepoint_xyz_one_event[:, 0], spacepoint_xyz_one_event[:, 1], s=0.1)
plt.xlabel("x")
plt.ylabel("y")
plt.title("recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]\n wcpplus_port_file")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyInFileError                            Traceback (most recent call last)
# Cell In[12], line 4
#       1 # 1.2 MB
#       2 f = uproot.open(nominal_ntuple_file)
# ----> 4 spacepoint_xyz_by_event = f["Events"]["recob::SpacePoints_portedSpacePointsThreshold__PortRedux.obj.fXYZ[3]"].array(library="np")
#       6 spacepoint_xyz_one_event = spacepoint_xyz_by_event[8]
#       8 print(spacepoint_xyz_one_event.shape)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/base_2/lib/python3.10/site-packages/uproot/reading.py:2108, in ReadOnlyDirectory.__getitem__(self, where)
#    2105     return step
#    2107 else:
# -> 2108     return self.key(where).get()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/base_2/lib/python3.10/site-packages/uproot/reading.py:2058, in ReadOnlyDirectory.key(self, where)
#    2056     return last
#    2057 elif cycle is None:
# -> 2058     raise uproot.KeyInFileError(
# ...
